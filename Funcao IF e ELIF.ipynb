# %%
nr1 = 6
nr2 = 6

#se esta condição for verdadeira:
if nr1 > nr2:
    print("A Var nr1 é maior q a var nr2")

#Senão, se essa for verdadeira:
elif nr1 == nr2:
    print("O número da var nr1 é igual à var nr2")
# Out:
# O número da var nr1 é igual à var nr2

# %%
#EXERCÍCIO - NR SECRETO

keynr = 7

tent = int(input("Digite um número inteiro entre 1 e 10 e descubra se você acertou:"))

if tent == keynr :
    print("Você acertou!")
else:
    print("Tente novamente!")
# Out:
# Digite um número inteiro entre 1 e 10 e descubra se você acertou: 7
# Você acertou!

# %%
#EXERCÍCIO 2

#Idade mímina para votar:
idvote = 18
validade = int(input("Informe sua idade:"))

# "==" é quando o valor deve ser igual
# ">=" ou "<=" é quando o valor de e ser maior ou menor ou igual
if validade >= idvote:
    print("Você tem idade mínima para votar")
else:
    print("Você não tem idade mínima para votar")
# Out:
# Informe sua idade: 22
# Você tem idade mínima para votar
